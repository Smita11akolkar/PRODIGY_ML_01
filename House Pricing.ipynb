# %% [markdown]
# ***PROBLEM STATEMENT***

# %% [markdown]
# Implement a linear regression model to predict the prices of house based on their square footage and the number of bedrooms and bathrooms.

# %% [markdown]
# ***Importing libraries***

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***Importing Dataset***

# %%
df=pd.read_csv("C:\\Users\\Smita Akolkar\\OneDrive\\Attachments\\Desktop\\Project Data\\Home Prices.csv")
df.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %% [raw]
# ##Data Description
# 1)area=area of house in square foot
# 2)bedrooms=No of bedrooms in house
# 3)age=Age of the building
# 4)price=Price of the building

# %%
##Describing the data
df.describe()
# Out:
#               area  bedrooms       age          price
# count     5.000000  4.000000   5.00000       5.000000
# mean   3280.000000  3.750000  18.20000  616000.000000
# std     540.370243  0.957427   8.01249   83919.604384
# min    2600.000000  3.000000   8.00000  550000.000000
# 25%    3000.000000  3.000000  15.00000  565000.000000
# 50%    3200.000000  3.500000  18.00000  595000.000000
# 75%    3600.000000  4.250000  20.00000  610000.000000
# max    4000.000000  5.000000  30.00000  760000.000000

# %%
##Finding information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   area      5 non-null      int64
#  1   bedrooms  4 non-null      float64
#  2   age       5 non-null      int64
#  3   price     5 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 292.0 bytes

# %% [markdown]
# bedroom has 1 null value

# %%
median=math.floor(df["bedrooms"].median())
median
# Out:
# 3

# %%
import math
df["bedrooms"]=df["bedrooms"].fillna(median)
df.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
plt.scatter(df["area"],df["price"])

# %%
##Fixing the values for x and y
x=df.drop(["price"],axis="columns")

##fitting y

y=df.price

# %%
##Fitting linear model

model=linear_model.LinearRegression()

model.fit(x,y)
# Out:
# LinearRegression()

# %%
##coefficient of regression

model.coef_

print("coefficient of regression is :",model.coef_)

model.intercept_

print("Intercept of regression is :",model.intercept_)
# Out:
# coefficient of regression is : [   137.25 -26025.    -6825.  ]
# Intercept of regression is : 383724.9999999998

# %%
##Predicting the price for 5000sq foot ,5 bedrooms,5 years of age

model.predict([[5000,5,5]])
# Out:
# array([905725.])

# %% [markdown]
# Approximately price would be Rs 905725
